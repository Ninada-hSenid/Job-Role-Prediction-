# %%
import time
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
import pandas as pd
# from keras.models import Sequential
# from keras.layers import Dense, Activation

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)

# %%
roo = '../Data/roo1.csv'
df  = pd.read_csv(roo)

data      = df.copy()
train_set = data.sample(frac=0.80645)
test_set  = data.drop(train_set.index)

print(train_set.shape,test_set.shape)
# Out:
# (16129, 99) (3871, 99)

# %%
print(train_set.head())
print(train_set.columns)
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 17824                                        68                        68
# 13792                                        76                        64
# 18271                                        73                        62
# 5016                                         66                        83
# 17586                                        90                        81
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# 17824                                  84                                  60
# 13792                                  62                                  78
# 18271                                  70                                  81
# 5016                                   71                                  78
# 17586                                  62                                  74
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# 17824                               83                                  78
# 13792                               71                                  67
# 18271                               81                                  81
# 5016                                81                                  80
# 17586                               75                                  84
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# 17824                                   72                         89
# 13792                                   65                         91
# 18271                                   73                         68
# 5016                                    64                         80
# 17586                                   61                         62
#
#        Percentage in Communication skills  Hours working per day  ...  \
# 17824                                  65                      8  ...
# 13792                                  89                      6  ...
# 18271                                  75                     11  ...
# 5016                                   66                      7  ...
# 17586                                  69                      5  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# 17824                         1                          0             0
# 13792                         1                          0             0
# 18271                         1                          0             0
# 5016                          1                          0             0
# 17586                         0                          1             1
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# 17824              1                                                 0
# 13792              1                                                 0
# 18271              1                                                 0
# 5016               1                                                 0
# 17586              0                                                 0
#
#        Suggested Job Role_Database Administrator  \
# 17824                                          0
# 13792                                          0
# 18271                                          0
# 5016                                           0
# 17586                                          0
#
#        Suggested Job Role_Project Manager  \
# 17824                                   1
# 13792                                   0
# 18271                                   0
# 5016                                    1
# 17586                                   0
#
#        Suggested Job Role_Security Administrator  \
# 17824                                          0
# 13792                                          1
# 18271                                          1
# 5016                                           0
# 17586                                          0
#
#        Suggested Job Role_Software Developer  \
# 17824                                      0
# 13792                                      0
# 18271                                      0
# 5016                                       0
# 17586                                      0
#
#        Suggested Job Role_Technical Support
# 17824                                     0
# 13792                                     0
# 18271                                     0
# 5016                                      0
# 17586                                     1
#
# [5 rows x 99 columns]
# Index(['Acedamic percentage in Operating Systems', 'percentage in Algorithms',
#        'Percentage in Programming Concepts',
#        'Percentage in Software Engineering', 'Percentage in Computer Networks',
#        'Percentage in Electronics Subjects',
#        'Percentage in Computer Architecture', 'Percentage in Mathematics',
#        'Percentage in Communication skills', 'Hours working per day',
#        'Logical quotient rating', 'hackathons', 'coding skills rating',
#        'public speaking points', 'can work long time before system?_no',
#        'can work long time before system?_yes', 'self-learning capability?_no',
#        'self-learning capability?_yes', 'Extra-courses did_no',
#        'Extra-courses did_yes', 'certifications_app development',
#        'certifications_distro making', 'certifications_full stack',
#        'certifications_hadoop', 'certifications_information security',
#        'certifications_machine learning', 'certifications_python',
#        'certifications_r programming', 'certifications_shell programming',
#        'workshops_cloud computing', 'workshops_data science',
#        'workshops_database security', 'workshops_game development',
#        'workshops_hacking', 'workshops_system designing', 'workshops_testing',
#        'workshops_web technologies', 'talenttests taken?_no',
#        'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes',
#        'reading and writing skills_excellent',
#        'reading and writing skills_medium', 'reading and writing skills_poor',
#        'memory capability score_excellent', 'memory capability score_medium',
#        'memory capability score_poor',
#        'Interested subjects_Computer Architecture', 'Interested subjects_IOT',
#        'Interested subjects_Management',
#        'Interested subjects_Software Engineering',
#        'Interested subjects_cloud computing',
#        'Interested subjects_data engineering', 'Interested subjects_hacking',
#        'Interested subjects_networks',
#        'Interested subjects_parallel computing',
#        'Interested subjects_programming',
#        'interested career area _Business process analyst',
#        'interested career area _cloud computing',
#        'interested career area _developer', 'interested career area _security',
#        'interested career area _system developer',
#        'interested career area _testing', 'Job/Higher Studies?_higherstudies',
#        'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA',
#        'Type of company want to settle in?_Cloud Services',
#        'Type of company want to settle in?_Finance',
#        'Type of company want to settle in?_Product based',
#        'Type of company want to settle in?_SAaS services',
#        'Type of company want to settle in?_Sales and Marketing',
#        'Type of company want to settle in?_Service Based',
#        'Type of company want to settle in?_Testing and Maintainance Services',
#        'Type of company want to settle in?_Web Services',
#        'Type of company want to settle in?_product development',
#        'Taken inputs from seniors or elders_no',
#        'Taken inputs from seniors or elders_yes', 'interested in games_no',
#        'interested in games_yes', 'In a Realtionship?_no',
#        'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle',
#        'Gentle or Tuff behaviour?_stubborn',
#        'Management or Technical_Management',
#        'Management or Technical_Technical', 'Salary/work_salary',
#        'Salary/work_work', 'hard/smart worker_hard worker',
#        'hard/smart worker_smart worker', 'worked in teams ever?_no',
#        'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes',
#        'Suggested Job Role_Business Intelligence Analyst',
#        'Suggested Job Role_Database Administrator',
#        'Suggested Job Role_Project Manager',
#        'Suggested Job Role_Security Administrator',
#        'Suggested Job Role_Software Developer',
#        'Suggested Job Role_Technical Support'],
#       dtype='object')

# %%
print(train_set.isnull().sum())
# Out:
# Acedamic percentage in Operating Systems     0
# percentage in Algorithms                     0
# Percentage in Programming Concepts           0
# Percentage in Software Engineering           0
# Percentage in Computer Networks              0
#                                             ..
# Suggested Job Role_Database Administrator    0
# Suggested Job Role_Project Manager           0
# Suggested Job Role_Security Administrator    0
# Suggested Job Role_Software Developer        0
# Suggested Job Role_Technical Support         0
# Length: 99, dtype: int64

# %%
print(train_set.dtypes.value_counts())
# Out:
# int64    99
# Name: count, dtype: int64

# %%
print(train_set.describe())
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# count                              16129.000000              16129.000000
# mean                                  76.968442                 76.912022
# std                                   10.095787                 10.091404
# min                                   60.000000                 60.000000
# 25%                                   68.000000                 68.000000
# 50%                                   77.000000                 77.000000
# 75%                                   86.000000                 86.000000
# max                                   94.000000                 94.000000
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# count                        16129.000000                        16129.000000
# mean                            77.016430                           77.107632
# std                             10.152436                           10.115930
# min                             60.000000                           60.000000
# 25%                             68.000000                           68.000000
# 50%                             77.000000                           77.000000
# 75%                             86.000000                           86.000000
# max                             94.000000                           94.000000
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# count                     16129.000000                        16129.000000
# mean                         76.903466                           76.987104
# std                          10.028020                           10.163304
# min                          60.000000                           60.000000
# 25%                          68.000000                           68.000000
# 50%                          77.000000                           77.000000
# 75%                          85.000000                           86.000000
# max                          94.000000                           94.000000
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# count                         16129.000000               16129.000000
# mean                             77.092752                  76.934156
# std                              10.056405                  10.176847
# min                              60.000000                  60.000000
# 25%                              68.000000                  68.000000
# 50%                              77.000000                  77.000000
# 75%                              86.000000                  86.000000
# max                              94.000000                  94.000000
#
#        Percentage in Communication skills  Hours working per day  ...  \
# count                        16129.000000           16129.000000  ...
# mean                            76.864282               7.981400  ...
# std                             10.083407               2.591701  ...
# min                             60.000000               4.000000  ...
# 25%                             68.000000               6.000000  ...
# 50%                             77.000000               8.000000  ...
# 75%                             86.000000              10.000000  ...
# max                             94.000000              12.000000  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# count              16129.000000               16129.000000  16129.000000
# mean                   0.499287                   0.500713      0.492095
# std                    0.500015                   0.500015      0.499953
# min                    0.000000                   0.000000      0.000000
# 25%                    0.000000                   0.000000      0.000000
# 50%                    0.000000                   1.000000      0.000000
# 75%                    1.000000                   1.000000      1.000000
# max                    1.000000                   1.000000      1.000000
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# count   16129.000000                                      16129.000000
# mean        0.507905                                          0.191952
# std         0.499953                                          0.393848
# min         0.000000                                          0.000000
# 25%         0.000000                                          0.000000
# 50%         1.000000                                          0.000000
# 75%         1.000000                                          0.000000
# max         1.000000                                          1.000000
#
#        Suggested Job Role_Database Administrator  \
# count                               16129.000000
# mean                                    0.087296
# std                                     0.282277
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Project Manager  \
# count                         16129.00000
# mean                              0.20739
# std                               0.40545
# min                               0.00000
# 25%                               0.00000
# 50%                               0.00000
# 75%                               0.00000
# max                               1.00000
#
#        Suggested Job Role_Security Administrator  \
# count                               16129.000000
# mean                                    0.174344
# std                                     0.379417
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Software Developer  \
# count                           16129.000000
# mean                                0.195796
# std                                 0.396825
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Suggested Job Role_Technical Support
# count                          16129.000000
# mean                               0.143220
# std                                0.350308
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
# [8 rows x 99 columns]

# %%
print(train_set.columns.tolist())
# Out:
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points', 'can work long time before system?_no', 'can work long time before system?_yes', 'self-learning capability?_no', 'self-learning capability?_yes', 'Extra-courses did_no', 'Extra-courses did_yes', 'certifications_app development', 'certifications_distro making', 'certifications_full stack', 'certifications_hadoop', 'certifications_information security', 'certifications_machine learning', 'certifications_python', 'certifications_r programming', 'certifications_shell programming', 'workshops_cloud computing', 'workshops_data science', 'workshops_database security', 'workshops_game development', 'workshops_hacking', 'workshops_system designing', 'workshops_testing', 'workshops_web technologies', 'talenttests taken?_no', 'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes', 'reading and writing skills_excellent', 'reading and writing skills_medium', 'reading and writing skills_poor', 'memory capability score_excellent', 'memory capability score_medium', 'memory capability score_poor', 'Interested subjects_Computer Architecture', 'Interested subjects_IOT', 'Interested subjects_Management', 'Interested subjects_Software Engineering', 'Interested subjects_cloud computing', 'Interested subjects_data engineering', 'Interested subjects_hacking', 'Interested subjects_networks', 'Interested subjects_parallel computing', 'Interested subjects_programming', 'interested career area _Business process analyst', 'interested career area _cloud computing', 'interested career area _developer', 'interested career area _security', 'interested career area _system developer', 'interested career area _testing', 'Job/Higher Studies?_higherstudies', 'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA', 'Type of company want to settle in?_Cloud Services', 'Type of company want to settle in?_Finance', 'Type of company want to settle in?_Product based', 'Type of company want to settle in?_SAaS services', 'Type of company want to settle in?_Sales and Marketing', 'Type of company want to settle in?_Service Based', 'Type of company want to settle in?_Testing and Maintainance Services', 'Type of company want to settle in?_Web Services', 'Type of company want to settle in?_product development', 'Taken inputs from seniors or elders_no', 'Taken inputs from seniors or elders_yes', 'interested in games_no', 'interested in games_yes', 'In a Realtionship?_no', 'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle', 'Gentle or Tuff behaviour?_stubborn', 'Management or Technical_Management', 'Management or Technical_Technical', 'Salary/work_salary', 'Salary/work_work', 'hard/smart worker_hard worker', 'hard/smart worker_smart worker', 'worked in teams ever?_no', 'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes', 'Suggested Job Role_Business Intelligence Analyst', 'Suggested Job Role_Database Administrator', 'Suggested Job Role_Project Manager', 'Suggested Job Role_Security Administrator', 'Suggested Job Role_Software Developer', 'Suggested Job Role_Technical Support']

# %%
print(test_set.columns.tolist())
# Out:
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points', 'can work long time before system?_no', 'can work long time before system?_yes', 'self-learning capability?_no', 'self-learning capability?_yes', 'Extra-courses did_no', 'Extra-courses did_yes', 'certifications_app development', 'certifications_distro making', 'certifications_full stack', 'certifications_hadoop', 'certifications_information security', 'certifications_machine learning', 'certifications_python', 'certifications_r programming', 'certifications_shell programming', 'workshops_cloud computing', 'workshops_data science', 'workshops_database security', 'workshops_game development', 'workshops_hacking', 'workshops_system designing', 'workshops_testing', 'workshops_web technologies', 'talenttests taken?_no', 'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes', 'reading and writing skills_excellent', 'reading and writing skills_medium', 'reading and writing skills_poor', 'memory capability score_excellent', 'memory capability score_medium', 'memory capability score_poor', 'Interested subjects_Computer Architecture', 'Interested subjects_IOT', 'Interested subjects_Management', 'Interested subjects_Software Engineering', 'Interested subjects_cloud computing', 'Interested subjects_data engineering', 'Interested subjects_hacking', 'Interested subjects_networks', 'Interested subjects_parallel computing', 'Interested subjects_programming', 'interested career area _Business process analyst', 'interested career area _cloud computing', 'interested career area _developer', 'interested career area _security', 'interested career area _system developer', 'interested career area _testing', 'Job/Higher Studies?_higherstudies', 'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA', 'Type of company want to settle in?_Cloud Services', 'Type of company want to settle in?_Finance', 'Type of company want to settle in?_Product based', 'Type of company want to settle in?_SAaS services', 'Type of company want to settle in?_Sales and Marketing', 'Type of company want to settle in?_Service Based', 'Type of company want to settle in?_Testing and Maintainance Services', 'Type of company want to settle in?_Web Services', 'Type of company want to settle in?_product development', 'Taken inputs from seniors or elders_no', 'Taken inputs from seniors or elders_yes', 'interested in games_no', 'interested in games_yes', 'In a Realtionship?_no', 'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle', 'Gentle or Tuff behaviour?_stubborn', 'Management or Technical_Management', 'Management or Technical_Technical', 'Salary/work_salary', 'Salary/work_work', 'hard/smart worker_hard worker', 'hard/smart worker_smart worker', 'worked in teams ever?_no', 'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes', 'Suggested Job Role_Business Intelligence Analyst', 'Suggested Job Role_Database Administrator', 'Suggested Job Role_Project Manager', 'Suggested Job Role_Security Administrator', 'Suggested Job Role_Software Developer', 'Suggested Job Role_Technical Support']

# %%
def add_label_column(df):
    label_columns = [col for col in df.columns if col.startswith('Suggested Job Role_')]
    df['Label'] = df[label_columns].idxmax(axis=1).str.replace('Suggested Job Role_', '')
    return df

# %%
train_set = add_label_column(train_set)
test_set = add_label_column(test_set)

# %%
print(test_set.columns.tolist())
print(test_set.columns.tolist())
# Out:
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points', 'can work long time before system?_no', 'can work long time before system?_yes', 'self-learning capability?_no', 'self-learning capability?_yes', 'Extra-courses did_no', 'Extra-courses did_yes', 'certifications_app development', 'certifications_distro making', 'certifications_full stack', 'certifications_hadoop', 'certifications_information security', 'certifications_machine learning', 'certifications_python', 'certifications_r programming', 'certifications_shell programming', 'workshops_cloud computing', 'workshops_data science', 'workshops_database security', 'workshops_game development', 'workshops_hacking', 'workshops_system designing', 'workshops_testing', 'workshops_web technologies', 'talenttests taken?_no', 'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes', 'reading and writing skills_excellent', 'reading and writing skills_medium', 'reading and writing skills_poor', 'memory capability score_excellent', 'memory capability score_medium', 'memory capability score_poor', 'Interested subjects_Computer Architecture', 'Interested subjects_IOT', 'Interested subjects_Management', 'Interested subjects_Software Engineering', 'Interested subjects_cloud computing', 'Interested subjects_data engineering', 'Interested subjects_hacking', 'Interested subjects_networks', 'Interested subjects_parallel computing', 'Interested subjects_programming', 'interested career area _Business process analyst', 'interested career area _cloud computing', 'interested career area _developer', 'interested career area _security', 'interested career area _system developer', 'interested career area _testing', 'Job/Higher Studies?_higherstudies', 'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA', 'Type of company want to settle in?_Cloud Services', 'Type of company want to settle in?_Finance', 'Type of company want to settle in?_Product based', 'Type of company want to settle in?_SAaS services', 'Type of company want to settle in?_Sales and Marketing', 'Type of company want to settle in?_Service Based', 'Type of company want to settle in?_Testing and Maintainance Services', 'Type of company want to settle in?_Web Services', 'Type of company want to settle in?_product development', 'Taken inputs from seniors or elders_no', 'Taken inputs from seniors or elders_yes', 'interested in games_no', 'interested in games_yes', 'In a Realtionship?_no', 'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle', 'Gentle or Tuff behaviour?_stubborn', 'Management or Technical_Management', 'Management or Technical_Technical', 'Salary/work_salary', 'Salary/work_work', 'hard/smart worker_hard worker', 'hard/smart worker_smart worker', 'worked in teams ever?_no', 'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes', 'Suggested Job Role_Business Intelligence Analyst', 'Suggested Job Role_Database Administrator', 'Suggested Job Role_Project Manager', 'Suggested Job Role_Security Administrator', 'Suggested Job Role_Software Developer', 'Suggested Job Role_Technical Support', 'Label']
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points', 'can work long time before system?_no', 'can work long time before system?_yes', 'self-learning capability?_no', 'self-learning capability?_yes', 'Extra-courses did_no', 'Extra-courses did_yes', 'certifications_app development', 'certifications_distro making', 'certifications_full stack', 'certifications_hadoop', 'certifications_information security', 'certifications_machine learning', 'certifications_python', 'certifications_r programming', 'certifications_shell programming', 'workshops_cloud computing', 'workshops_data science', 'workshops_database security', 'workshops_game development', 'workshops_hacking', 'workshops_system designing', 'workshops_testing', 'workshops_web technologies', 'talenttests taken?_no', 'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes', 'reading and writing skills_excellent', 'reading and writing skills_medium', 'reading and writing skills_poor', 'memory capability score_excellent', 'memory capability score_medium', 'memory capability score_poor', 'Interested subjects_Computer Architecture', 'Interested subjects_IOT', 'Interested subjects_Management', 'Interested subjects_Software Engineering', 'Interested subjects_cloud computing', 'Interested subjects_data engineering', 'Interested subjects_hacking', 'Interested subjects_networks', 'Interested subjects_parallel computing', 'Interested subjects_programming', 'interested career area _Business process analyst', 'interested career area _cloud computing', 'interested career area _developer', 'interested career area _security', 'interested career area _system developer', 'interested career area _testing', 'Job/Higher Studies?_higherstudies', 'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA', 'Type of company want to settle in?_Cloud Services', 'Type of company want to settle in?_Finance', 'Type of company want to settle in?_Product based', 'Type of company want to settle in?_SAaS services', 'Type of company want to settle in?_Sales and Marketing', 'Type of company want to settle in?_Service Based', 'Type of company want to settle in?_Testing and Maintainance Services', 'Type of company want to settle in?_Web Services', 'Type of company want to settle in?_product development', 'Taken inputs from seniors or elders_no', 'Taken inputs from seniors or elders_yes', 'interested in games_no', 'interested in games_yes', 'In a Realtionship?_no', 'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle', 'Gentle or Tuff behaviour?_stubborn', 'Management or Technical_Management', 'Management or Technical_Technical', 'Salary/work_salary', 'Salary/work_work', 'hard/smart worker_hard worker', 'hard/smart worker_smart worker', 'worked in teams ever?_no', 'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes', 'Suggested Job Role_Business Intelligence Analyst', 'Suggested Job Role_Database Administrator', 'Suggested Job Role_Project Manager', 'Suggested Job Role_Security Administrator', 'Suggested Job Role_Software Developer', 'Suggested Job Role_Technical Support', 'Label']

# %%
print("Train labels:", train_set['Label'].unique())
print("Test labels:", test_set['Label'].unique())

print("Train label counts:")
print(train_set['Label'].value_counts())

print("\nTest label counts:")
print(test_set['Label'].value_counts())
# Out:
# Train labels: ['Project Manager' 'Security Administrator' 'Technical Support'
#  'Software Developer' 'Business Intelligence Analyst'
#  'Database Administrator']
# Test labels: ['Database Administrator' 'Business Intelligence Analyst'
#  'Software Developer' 'Security Administrator' 'Technical Support'
#  'Project Manager']
# Train label counts:
# Label
# Project Manager                  3277
# Software Developer               3202
# Business Intelligence Analyst    3133
# Security Administrator           2790
# Technical Support                2296
# Database Administrator           1431
# Name: count, dtype: int64
#
# Test label counts:
# Label
# Project Manager                  822
# Software Developer               766
# Business Intelligence Analyst    756
# Security Administrator           678
# Technical Support                536
# Database Administrator           313
# Name: count, dtype: int64

# %%
# Drop one-hot encoded label columns from features
label_columns = [
    'Suggested Job Role_Project Manager',
    'Suggested Job Role_Software Developer',
    'Suggested Job Role_Business Intelligence Analyst',
    'Suggested Job Role_Security Administrator',
    'Suggested Job Role_Technical Support',
    'Suggested Job Role_Database Administrator'
]

X_train = train_set.drop(columns=label_columns + ['Label'])
y_train = train_set['Label']

X_test = test_set.drop(columns=label_columns + ['Label'])
y_test = test_set['Label']

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (16129, 93)
# y_train shape: (16129,)
# X_test shape: (3871, 93)
# y_test shape: (3871,)

# %%
print(train_set.isnull().sum())
# Out:
# Acedamic percentage in Operating Systems     0
# percentage in Algorithms                     0
# Percentage in Programming Concepts           0
# Percentage in Software Engineering           0
# Percentage in Computer Networks              0
#                                             ..
# Suggested Job Role_Security Administrator    0
# Suggested Job Role_Software Developer        0
# Suggested Job Role_Technical Support         0
# Suggested Job Role Label                     0
# Label                                        0
# Length: 101, dtype: int64

# %%
print(train_set.isnull().sum().sum())  # total missing values
print(test_set.isnull().sum().sum())
# Out:
# 0
# 0

# %%
print(train_set.describe(include='all').transpose())
# Out:
#                                              count unique              top  \
# Acedamic percentage in Operating Systems   16129.0    NaN              NaN
# percentage in Algorithms                   16129.0    NaN              NaN
# Percentage in Programming Concepts         16129.0    NaN              NaN
# Percentage in Software Engineering         16129.0    NaN              NaN
# Percentage in Computer Networks            16129.0    NaN              NaN
# ...                                            ...    ...              ...
# Suggested Job Role_Security Administrator  16129.0    NaN              NaN
# Suggested Job Role_Software Developer      16129.0    NaN              NaN
# Suggested Job Role_Technical Support       16129.0    NaN              NaN
# Suggested Job Role Label                     16129      6  Project Manager
# Label                                        16129      6  Project Manager
#
#                                            freq       mean        std   min  \
# Acedamic percentage in Operating Systems    NaN  76.968442  10.095787  60.0
# percentage in Algorithms                    NaN  76.912022  10.091404  60.0
# Percentage in Programming Concepts          NaN   77.01643  10.152436  60.0
# Percentage in Software Engineering          NaN  77.107632   10.11593  60.0
# Percentage in Computer Networks             NaN  76.903466   10.02802  60.0
# ...                                         ...        ...        ...   ...
# Suggested Job Role_Security Administrator   NaN   0.174344   0.379417   0.0
# Suggested Job Role_Software Developer       NaN   0.195796   0.396825   0.0
# Suggested Job Role_Technical Support        NaN    0.14322   0.350308   0.0
# Suggested Job Role Label                   3345        NaN        NaN   NaN
# Label                                      3345        NaN        NaN   NaN
#
#                                             25%   50%   75%   max
# Acedamic percentage in Operating Systems   68.0  77.0  86.0  94.0
# percentage in Algorithms                   68.0  77.0  86.0  94.0
# Percentage in Programming Concepts         68.0  77.0  86.0  94.0
# Percentage in Software Engineering         68.0  77.0  86.0  94.0
# Percentage in Computer Networks            68.0  77.0  85.0  94.0
# ...                                         ...   ...   ...   ...
# Suggested Job Role_Security Administrator   0.0   0.0   0.0   1.0
# Suggested Job Role_Software Developer       0.0   0.0   0.0   1.0
# Suggested Job Role_Technical Support        0.0   0.0   0.0   1.0
# Suggested Job Role Label                    NaN   NaN   NaN   NaN
# Label                                       NaN   NaN   NaN   NaN
#
# [101 rows x 11 columns]

# %%
# Filter numeric columns only
numeric_df = df.select_dtypes(include=['number'])

# Find columns where all values are within [0, 100]
cols_in_0_100_range = [
    col for col in numeric_df.columns
    if numeric_df[col].min() >= 0 and numeric_df[col].max() <= 100
]

print("✅ Columns with all values in the range 0–100:")
print(cols_in_0_100_range)
# Out:
# ✅ Columns with all values in the range 0–100:
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points', 'can work long time before system?_no', 'can work long time before system?_yes', 'self-learning capability?_no', 'self-learning capability?_yes', 'Extra-courses did_no', 'Extra-courses did_yes', 'certifications_app development', 'certifications_distro making', 'certifications_full stack', 'certifications_hadoop', 'certifications_information security', 'certifications_machine learning', 'certifications_python', 'certifications_r programming', 'certifications_shell programming', 'workshops_cloud computing', 'workshops_data science', 'workshops_database security', 'workshops_game development', 'workshops_hacking', 'workshops_system designing', 'workshops_testing', 'workshops_web technologies', 'talenttests taken?_no', 'talenttests taken?_yes', 'olympiads_no', 'olympiads_yes', 'reading and writing skills_excellent', 'reading and writing skills_medium', 'reading and writing skills_poor', 'memory capability score_excellent', 'memory capability score_medium', 'memory capability score_poor', 'Interested subjects_Computer Architecture', 'Interested subjects_IOT', 'Interested subjects_Management', 'Interested subjects_Software Engineering', 'Interested subjects_cloud computing', 'Interested subjects_data engineering', 'Interested subjects_hacking', 'Interested subjects_networks', 'Interested subjects_parallel computing', 'Interested subjects_programming', 'interested career area _Business process analyst', 'interested career area _cloud computing', 'interested career area _developer', 'interested career area _security', 'interested career area _system developer', 'interested career area _testing', 'Job/Higher Studies?_higherstudies', 'Job/Higher Studies?_job', 'Type of company want to settle in?_BPA', 'Type of company want to settle in?_Cloud Services', 'Type of company want to settle in?_Finance', 'Type of company want to settle in?_Product based', 'Type of company want to settle in?_SAaS services', 'Type of company want to settle in?_Sales and Marketing', 'Type of company want to settle in?_Service Based', 'Type of company want to settle in?_Testing and Maintainance Services', 'Type of company want to settle in?_Web Services', 'Type of company want to settle in?_product development', 'Taken inputs from seniors or elders_no', 'Taken inputs from seniors or elders_yes', 'interested in games_no', 'interested in games_yes', 'In a Realtionship?_no', 'In a Realtionship?_yes', 'Gentle or Tuff behaviour?_gentle', 'Gentle or Tuff behaviour?_stubborn', 'Management or Technical_Management', 'Management or Technical_Technical', 'Salary/work_salary', 'Salary/work_work', 'hard/smart worker_hard worker', 'hard/smart worker_smart worker', 'worked in teams ever?_no', 'worked in teams ever?_yes', 'Introvert_no', 'Introvert_yes', 'Suggested Job Role_Business Intelligence Analyst', 'Suggested Job Role_Database Administrator', 'Suggested Job Role_Project Manager', 'Suggested Job Role_Security Administrator', 'Suggested Job Role_Software Developer', 'Suggested Job Role_Technical Support']

# %%
def is_in_range_0_100(series):
    return series.dropna().between(0, 100).all()

def is_not_one_hot(series):
    # Checks if the column is not just 0 and 1 values (i.e., not one-hot encoded)
    return not (series.min() == 0 and series.max() == 1)

numeric_0_100_cols = []
for col in train_set.columns:
    if pd.api.types.is_numeric_dtype(train_set[col]):
        if is_in_range_0_100(train_set[col]) and is_not_one_hot(train_set[col]):
            numeric_0_100_cols.append(col)

print("Columns with values in 0-100 range (likely marks) and not one-hot:")
print(numeric_0_100_cols)

# Show first 5 rows of these columns for inspection
print(train_set[numeric_0_100_cols].head())
# Out:
# Columns with values in 0-100 range (likely marks) and not one-hot:
# ['Acedamic percentage in Operating Systems', 'percentage in Algorithms', 'Percentage in Programming Concepts', 'Percentage in Software Engineering', 'Percentage in Computer Networks', 'Percentage in Electronics Subjects', 'Percentage in Computer Architecture', 'Percentage in Mathematics', 'Percentage in Communication skills', 'Hours working per day', 'Logical quotient rating', 'hackathons', 'coding skills rating', 'public speaking points']
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 11456                                        80                        93
# 16528                                        81                        80
# 3253                                         92                        91
# 18614                                        85                        76
# 1544                                         60                        68
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# 11456                                  84                                  82
# 16528                                  69                                  89
# 3253                                   70                                  83
# 18614                                  92                                  68
# 1544                                   60                                  87
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# 11456                               71                                  71
# 16528                               84                                  64
# 3253                                66                                  84
# 18614                               77                                  83
# 1544                                61                                  71
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# 11456                                   81                         69
# 16528                                   82                         77
# 3253                                    64                         75
# 18614                                   66                         83
# 1544                                    90                         90
#
#        Percentage in Communication skills  Hours working per day  \
# 11456                                  86                     12
# 16528                                  67                      9
# 3253                                   65                      4
# 18614                                  88                      6
# 1544                                   69                      9
#
#        Logical quotient rating  hackathons  coding skills rating  \
# 11456                        5           6                     1
# 16528                        4           5                     3
# 3253                         9           4                     8
# 18614                        8           6                     2
# 1544                         7           2                     1
#
#        public speaking points
# 11456                       2
# 16528                       9
# 3253                        4
# 18614                       7
# 1544                        4

# %%
train_set.describe()
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# count                              16129.000000              16129.000000
# mean                                  77.003100                 76.907930
# std                                   10.071649                 10.099991
# min                                   60.000000                 60.000000
# 25%                                   68.000000                 68.000000
# 50%                                   77.000000                 77.000000
# 75%                                   86.000000                 86.000000
# max                                   94.000000                 94.000000
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# count                        16129.000000                        16129.000000
# mean                            77.013020                           77.109802
# std                             10.141849                           10.076335
# min                             60.000000                           60.000000
# 25%                             68.000000                           68.000000
# 50%                             77.000000                           77.000000
# 75%                             86.000000                           86.000000
# max                             94.000000                           94.000000
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# count                     16129.000000                        16129.000000
# mean                         76.930002                           77.014570
# std                          10.023255                           10.160925
# min                          60.000000                           60.000000
# 25%                          68.000000                           68.000000
# 50%                          77.000000                           77.000000
# 75%                          85.000000                           86.000000
# max                          94.000000                           94.000000
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# count                         16129.000000               16129.000000
# mean                             77.074152                  76.912580
# std                              10.073303                  10.107632
# min                              60.000000                  60.000000
# 25%                              68.000000                  68.000000
# 50%                              77.000000                  77.000000
# 75%                              86.000000                  86.000000
# max                              94.000000                  94.000000
#
#        Percentage in Communication skills  Hours working per day  ...  \
# count                        16129.000000           16129.000000  ...
# mean                            76.897886               7.997520  ...
# std                             10.084307               2.594756  ...
# min                             60.000000               4.000000  ...
# 25%                             68.000000               6.000000  ...
# 50%                             77.000000               8.000000  ...
# 75%                             86.000000              10.000000  ...
# max                             94.000000              12.000000  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# count              16129.000000               16129.000000  16129.000000
# mean                   0.503751                   0.496249      0.492591
# std                    0.500001                   0.500001      0.499961
# min                    0.000000                   0.000000      0.000000
# 25%                    0.000000                   0.000000      0.000000
# 50%                    1.000000                   0.000000      0.000000
# 75%                    1.000000                   1.000000      1.000000
# max                    1.000000                   1.000000      1.000000
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# count   16129.000000                                      16129.000000
# mean        0.507409                                          0.194246
# std         0.499961                                          0.395632
# min         0.000000                                          0.000000
# 25%         0.000000                                          0.000000
# 50%         1.000000                                          0.000000
# 75%         1.000000                                          0.000000
# max         1.000000                                          1.000000
#
#        Suggested Job Role_Database Administrator  \
# count                               16129.000000
# mean                                    0.088722
# std                                     0.284351
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Project Manager  \
# count                        16129.000000
# mean                             0.203174
# std                              0.402374
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Suggested Job Role_Security Administrator  \
# count                               16129.000000
# mean                                    0.172980
# std                                     0.378242
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Software Developer  \
# count                           16129.000000
# mean                                0.198524
# std                                 0.398901
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Suggested Job Role_Technical Support
# count                          16129.000000
# mean                               0.142352
# std                                0.349422
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
# [8 rows x 99 columns]

# %%
def normalize_percentage_columns(df):
    percentage_cols = [col for col in df.columns if 'percentage in' in col.lower()]
    df = df.copy()
    for col in percentage_cols:
        df[col] = (df[col] - 60) / 40  # (value - min) / (max - min)
    return df

# Apply to train_set and test_set
train_set = normalize_percentage_columns(train_set)
test_set = normalize_percentage_columns(test_set)

# %%
train_set.describe()
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# count                              16129.000000              16129.000000
# mean                                   0.770031                  0.769079
# std                                    0.100716                  0.101000
# min                                    0.600000                  0.600000
# 25%                                    0.680000                  0.680000
# 50%                                    0.770000                  0.770000
# 75%                                    0.860000                  0.860000
# max                                    0.940000                  0.940000
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# count                        16129.000000                        16129.000000
# mean                             0.770130                            0.771098
# std                              0.101418                            0.100763
# min                              0.600000                            0.600000
# 25%                              0.680000                            0.680000
# 50%                              0.770000                            0.770000
# 75%                              0.860000                            0.860000
# max                              0.940000                            0.940000
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# count                     16129.000000                        16129.000000
# mean                          0.769300                            0.770146
# std                           0.100233                            0.101609
# min                           0.600000                            0.600000
# 25%                           0.680000                            0.680000
# 50%                           0.770000                            0.770000
# 75%                           0.850000                            0.860000
# max                           0.940000                            0.940000
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# count                         16129.000000               16129.000000
# mean                              0.770742                   0.769126
# std                               0.100733                   0.101076
# min                               0.600000                   0.600000
# 25%                               0.680000                   0.680000
# 50%                               0.770000                   0.770000
# 75%                               0.860000                   0.860000
# max                               0.940000                   0.940000
#
#        Percentage in Communication skills  Hours working per day  ...  \
# count                        16129.000000           16129.000000  ...
# mean                             0.768979               7.997520  ...
# std                              0.100843               2.594756  ...
# min                              0.600000               4.000000  ...
# 25%                              0.680000               6.000000  ...
# 50%                              0.770000               8.000000  ...
# 75%                              0.860000              10.000000  ...
# max                              0.940000              12.000000  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# count              16129.000000               16129.000000  16129.000000
# mean                   0.503751                   0.496249      0.492591
# std                    0.500001                   0.500001      0.499961
# min                    0.000000                   0.000000      0.000000
# 25%                    0.000000                   0.000000      0.000000
# 50%                    1.000000                   0.000000      0.000000
# 75%                    1.000000                   1.000000      1.000000
# max                    1.000000                   1.000000      1.000000
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# count   16129.000000                                      16129.000000
# mean        0.507409                                          0.194246
# std         0.499961                                          0.395632
# min         0.000000                                          0.000000
# 25%         0.000000                                          0.000000
# 50%         1.000000                                          0.000000
# 75%         1.000000                                          0.000000
# max         1.000000                                          1.000000
#
#        Suggested Job Role_Database Administrator  \
# count                               16129.000000
# mean                                    0.088722
# std                                     0.284351
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Project Manager  \
# count                        16129.000000
# mean                             0.203174
# std                              0.402374
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Suggested Job Role_Security Administrator  \
# count                               16129.000000
# mean                                    0.172980
# std                                     0.378242
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Software Developer  \
# count                           16129.000000
# mean                                0.198524
# std                                 0.398901
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Suggested Job Role_Technical Support
# count                          16129.000000
# mean                               0.142352
# std                                0.349422
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
# [8 rows x 99 columns]

# %%
max_hours = train_set['Hours working per day'].max()
print(f"Maximum hours working per day: {max_hours}")
# Out:
# Maximum hours working per day: 12

# %%
def normalize_by_max(df, columns):
    for col in columns:
        max_val = df[col].max()
        if max_val > 0:
            df[col] = df[col] / max_val
        else:
            print(f"Warning: Max value for column '{col}' is {max_val}, skipping normalization.")
    return df

# Columns to normalize
cols_to_normalize = [
    'Hours working per day', 
    'Logical quotient rating', 
    'hackathons', 
    'coding skills rating', 
    'public speaking points'
]

# Apply to train and test sets
train_set = normalize_by_max(train_set, cols_to_normalize)
test_set = normalize_by_max(test_set, cols_to_normalize)

# %%
train_set.describe()
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# count                              16129.000000              16129.000000
# mean                                   0.770031                  0.769079
# std                                    0.100716                  0.101000
# min                                    0.600000                  0.600000
# 25%                                    0.680000                  0.680000
# 50%                                    0.770000                  0.770000
# 75%                                    0.860000                  0.860000
# max                                    0.940000                  0.940000
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# count                        16129.000000                        16129.000000
# mean                             0.770130                            0.771098
# std                              0.101418                            0.100763
# min                              0.600000                            0.600000
# 25%                              0.680000                            0.680000
# 50%                              0.770000                            0.770000
# 75%                              0.860000                            0.860000
# max                              0.940000                            0.940000
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# count                     16129.000000                        16129.000000
# mean                          0.769300                            0.770146
# std                           0.100233                            0.101609
# min                           0.600000                            0.600000
# 25%                           0.680000                            0.680000
# 50%                           0.770000                            0.770000
# 75%                           0.850000                            0.860000
# max                           0.940000                            0.940000
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# count                         16129.000000               16129.000000
# mean                              0.770742                   0.769126
# std                               0.100733                   0.101076
# min                               0.600000                   0.600000
# 25%                               0.680000                   0.680000
# 50%                               0.770000                   0.770000
# 75%                               0.860000                   0.860000
# max                               0.940000                   0.940000
#
#        Percentage in Communication skills  Hours working per day  ...  \
# count                        16129.000000           16129.000000  ...
# mean                             0.768979               0.666460  ...
# std                              0.100843               0.216230  ...
# min                              0.600000               0.333333  ...
# 25%                              0.680000               0.500000  ...
# 50%                              0.770000               0.666667  ...
# 75%                              0.860000               0.833333  ...
# max                              0.940000               1.000000  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# count              16129.000000               16129.000000  16129.000000
# mean                   0.503751                   0.496249      0.492591
# std                    0.500001                   0.500001      0.499961
# min                    0.000000                   0.000000      0.000000
# 25%                    0.000000                   0.000000      0.000000
# 50%                    1.000000                   0.000000      0.000000
# 75%                    1.000000                   1.000000      1.000000
# max                    1.000000                   1.000000      1.000000
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# count   16129.000000                                      16129.000000
# mean        0.507409                                          0.194246
# std         0.499961                                          0.395632
# min         0.000000                                          0.000000
# 25%         0.000000                                          0.000000
# 50%         1.000000                                          0.000000
# 75%         1.000000                                          0.000000
# max         1.000000                                          1.000000
#
#        Suggested Job Role_Database Administrator  \
# count                               16129.000000
# mean                                    0.088722
# std                                     0.284351
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Project Manager  \
# count                        16129.000000
# mean                             0.203174
# std                              0.402374
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Suggested Job Role_Security Administrator  \
# count                               16129.000000
# mean                                    0.172980
# std                                     0.378242
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Software Developer  \
# count                           16129.000000
# mean                                0.198524
# std                                 0.398901
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Suggested Job Role_Technical Support
# count                          16129.000000
# mean                               0.142352
# std                                0.349422
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
# [8 rows x 99 columns]

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
axes = axes.flatten()

for i, col in enumerate(cols_to_normalize):
    axes[i].hist(train_set[col], bins=20, color='skyblue', alpha=0.7)
    axes[i].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
test_set.describe()
# Out:
#        Acedamic percentage in Operating Systems  percentage in Algorithms  \
# count                               3871.000000               3871.000000
# mean                                   0.769990                  0.771160
# std                                    0.101453                  0.101086
# min                                    0.600000                  0.600000
# 25%                                    0.680000                  0.680000
# 50%                                    0.770000                  0.770000
# 75%                                    0.860000                  0.860000
# max                                    0.940000                  0.940000
#
#        Percentage in Programming Concepts  Percentage in Software Engineering  \
# count                         3871.000000                         3871.000000
# mean                             0.770364                            0.770307
# std                              0.101067                            0.101367
# min                              0.600000                            0.600000
# 25%                              0.680000                            0.680000
# 50%                              0.770000                            0.770000
# 75%                              0.860000                            0.860000
# max                              0.940000                            0.940000
#
#        Percentage in Computer Networks  Percentage in Electronics Subjects  \
# count                      3871.000000                         3871.000000
# mean                          0.770757                            0.770196
# std                           0.100073                            0.102033
# min                           0.600000                            0.600000
# 25%                           0.680000                            0.680000
# 50%                           0.770000                            0.770000
# 75%                           0.860000                            0.860000
# max                           0.940000                            0.940000
#
#        Percentage in Computer Architecture  Percentage in Mathematics  \
# count                          3871.000000                3871.000000
# mean                              0.770519                   0.769153
# std                               0.100526                   0.102677
# min                               0.600000                   0.600000
# 25%                               0.680000                   0.680000
# 50%                               0.770000                   0.770000
# 75%                               0.860000                   0.860000
# max                               0.940000                   0.940000
#
#        Percentage in Communication skills  Hours working per day  ...  \
# count                         3871.000000            3871.000000  ...
# mean                             0.770196               0.661479  ...
# std                              0.101838               0.215799  ...
# min                              0.600000               0.333333  ...
# 25%                              0.680000               0.500000  ...
# 50%                              0.770000               0.666667  ...
# 75%                              0.860000               0.833333  ...
# max                              0.940000               1.000000  ...
#
#        worked in teams ever?_no  worked in teams ever?_yes  Introvert_no  \
# count               3871.000000                3871.000000   3871.000000
# mean                   0.498321                   0.501679      0.505812
# std                    0.500062                   0.500062      0.500031
# min                    0.000000                   0.000000      0.000000
# 25%                    0.000000                   0.000000      0.000000
# 50%                    0.000000                   1.000000      1.000000
# 75%                    1.000000                   1.000000      1.000000
# max                    1.000000                   1.000000      1.000000
#
#        Introvert_yes  Suggested Job Role_Business Intelligence Analyst  \
# count    3871.000000                                       3871.000000
# mean        0.494188                                          0.195298
# std         0.500031                                          0.396481
# min         0.000000                                          0.000000
# 25%         0.000000                                          0.000000
# 50%         0.000000                                          0.000000
# 75%         1.000000                                          0.000000
# max         1.000000                                          1.000000
#
#        Suggested Job Role_Database Administrator  \
# count                                3871.000000
# mean                                    0.080858
# std                                     0.272652
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Project Manager  \
# count                         3871.000000
# mean                             0.212348
# std                              0.409023
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        Suggested Job Role_Security Administrator  \
# count                                3871.000000
# mean                                    0.175149
# std                                     0.380143
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        Suggested Job Role_Software Developer  \
# count                            3871.000000
# mean                                0.197882
# std                                 0.398454
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        Suggested Job Role_Technical Support
# count                           3871.000000
# mean                               0.138466
# std                                0.345433
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
# [8 rows x 99 columns]
